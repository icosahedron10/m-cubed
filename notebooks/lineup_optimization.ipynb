# %% [markdown]
# # Lineup optimization
# Compare greedy and integer programming lineups.

# %%
import pandas as pd
from march_madness_model.optimizer import compare_greedy_vs_optimal

results = pd.read_csv("simulation_results.csv")  # replace with CLI output
compare_greedy_vs_optimal(results, budget=100, roster_size=8)
