# %% [markdown]
# # Sensitivity analysis
# Explore changes in seed-only versus team-strength-adjusted assumptions.

# %%
from march_madness_model.probabilities import SeedProbabilityModel

SeedProbabilityModel(baseline_blend=0.5, strength_weight=0.3)
